# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
#os.chdir('../')

# %%
plt.rcParams['mathtext.fontset'] = 'cm'
plt.rcParams["font.family"] = "serif"
plt.rcParams["font.serif"] = ["Times New Roman"
                                                ] + plt.rcParams["font.serif"]
plt.rcParams['font.size'] = 13
plt.rcParams['figure.dpi'] = 300

# %% [markdown]
# # The Data

# %%
data = pd.read_excel('../data/data.xlsx')
data = data.drop(columns=['S/N'])
data.head()
# Out:
#    cDen  Pot  Sn %     pH  C2H4  CO  H2  EtoH  FORM
# 0   150  3.5   100  14.05     0  23  12     0    61
# 1   150  3.3    80  14.05     0  23   7     0    66
# 2   150  3.2    50  14.05     0  34   5     3    52
# 3   150  3.1    10  14.05     1  42   5     2    42
# 4   150  3.0     5  14.05     4  48   5    10    19

# %%
features_col = list(data.columns[:4])
target_col = list(data.columns[4:])
#target_col = [target_col[0], target_col[2]]
print('Features: ', features_col)
print('Target: ', target_col)
# Out:
# Features:  ['cDen', 'Pot', 'Sn %', 'pH']
# Target:  ['C2H4', 'CO', 'H2', 'EtoH', 'FORM']

# %%
# normalize the data in target columns by 100
data[target_col] = data[target_col] / 100
data.head(2)
# Out:
#    cDen  Pot  Sn %     pH  C2H4    CO    H2  EtoH  FORM
# 0   150  3.5   100  14.05   0.0  0.23  0.12   0.0  0.61
# 1   150  3.3    80  14.05   0.0  0.23  0.07   0.0  0.66

# %%
data.describe().transpose()
# Out:
#       count        mean         std     min      25%     50%      75%     max
# cDen   35.0  269.171429  119.205824  141.00  150.000  250.00  350.000  450.00
# Pot    35.0    3.860000    0.500118    2.80    3.550    4.00    4.150    4.70
# Sn %   35.0   35.428571   38.820314    0.00    3.000   10.00   80.000  100.00
# pH     35.0   12.844000    2.447214    8.02   14.050   14.05   14.050   14.05
# C2H4   35.0    0.079714    0.103483    0.00    0.000    0.04    0.095    0.37
# CO     35.0    0.219429    0.123120    0.05    0.125    0.19    0.275    0.50
# H2     35.0    0.137429    0.093442    0.05    0.070    0.10    0.155    0.37
# EtoH   35.0    0.106000    0.132114    0.00    0.000    0.06    0.140    0.48
# FORM   35.0    0.353714    0.217067    0.07    0.140    0.38    0.540    0.70

# %%
# normailze the data in features columns to range [0, 1]
minX = data[features_col].min()
maxX = data[features_col].max()

data[features_col] = (data[features_col] - minX) / (maxX - minX)
data.head(2)
# Out:
#        cDen       Pot  Sn %   pH  C2H4    CO    H2  EtoH  FORM
# 0  0.029126  0.368421   1.0  1.0   0.0  0.23  0.12   0.0  0.61
# 1  0.029126  0.263158   0.8  1.0   0.0  0.23  0.07   0.0  0.66

# %% [markdown]
# ## ML model

# %%
import torch

from botorch.models import SingleTaskGP
from gpytorch.kernels import LinearKernel, MaternKernel, RBFKernel, ScaleKernel

from botorch.models.transforms.outcome import Standardize

from gpytorch.mlls import ExactMarginalLogLikelihood
from botorch import fit_gpytorch_model
from sklearn.model_selection import train_test_split
from scipy.stats import norm
import numpy as np
from sklearn.metrics import r2_score, mean_absolute_error

# %%
def extract_train_data(data, idx, seed):
    X = data[features_col].values
    y = data[target_col[idx]].values

    ids_train, ids_test = train_test_split(range(X.shape[0]), test_size=0.25, random_state=seed)
    # train surrogate model for test data, on acquired set up till top COF was found.
    X_train = torch.from_numpy(X[ids_train, :])
    X_test  = torch.from_numpy(X[ids_test, :])

    y_train = torch.from_numpy(y[ids_train].reshape(-1, 1))
    y_test  = torch.from_numpy(y[ids_test].reshape(-1, 1))
    return X,  X_train, y_train, X_test, y_test

# %%
def retreive_model(idx, seed):

    X, X_train, y_train, X_test, y_test = extract_train_data(data=data, idx=idx, seed=seed)

    if idx == 0:
        kernel = MaternKernel()
    else:
        kernel = RBFKernel()
    
    gp = SingleTaskGP(X_train, y_train, outcome_transform=Standardize(m=1), covar_module=kernel)
    gp.load_state_dict(torch.load(f'../models/gp_{target_col[idx]}.pt'))

    return gp, X

# %%
gp_H2, X_train = retreive_model(idx=2, seed=0)
gp_ethane, _ = retreive_model(idx=0, seed=0)

# %%
features_col
# Out:
# ['cDen', 'Pot', 'Sn %', 'pH']

# %%
import pickle
def polymer_properties(x1, x2, x3, x4):
    """
    """
    # merge the input data
    X_ = np.column_stack((x1, x2, x3, x4))
    # load pickle and scale it
    # with open('../data/min_max_X.pkl', 'rb') as f:
    #     min_max_X = pickle.load(f)

    # print(min_max_X)

    # X_ = (X_ - min_max_X[0]) / (min_max_X[1] - min_max_X[0])
    
    X_ = torch.from_numpy(X_[:, :])

    gp_H2.eval()
    gp_ethane.eval()

    with torch.no_grad():
        y_H2 = gp_H2.posterior(X_).mean
        y_ethane = gp_ethane.posterior(X_).mean

    return {"C2H4" : float(y_ethane), "H2" : float(y_H2)}

# %%
x1 = 1 # np.linspace(0, 1, 100)
x2 = 1 #np.linspace(0, 1, 100)
x3 = 1 #np.linspace(0, 1, 100)
x4 = 1 #np.linspace(0, 1, 100)

polymer_properties(x1, x2, x3, x4)
# Out:
# {'C2H4': 0.013543507305906338, 'H2': 0.3265349355740676}

# %%
from ax.service.ax_client import AxClient, ObjectiveProperties

obj1_name = "C2H4" 
obj2_name = "H2"

# CHANGE: add the historical data that was pulled from the literature
X_train = data[features_col]

# CHANGE: calculate the y_train values using the polymer_properties function
y_train = data[[target_col[0], target_col[2]]]

# %%
for i in range(len(X_train)):
    print(f"i: {i}, X_train: {X_train.iloc[i]}, y_train: {y_train.iloc[i]}")
# Out:
# i: 0, X_train: cDen    0.029126
# Pot     0.368421
# Sn %    1.000000
# pH      1.000000
# Name: 0, dtype: float64, y_train: C2H4    0.00
# H2      0.12
# Name: 0, dtype: float64
# i: 1, X_train: cDen    0.029126
# Pot     0.263158
# Sn %    0.800000
# pH      1.000000
# Name: 1, dtype: float64, y_train: C2H4    0.00
# H2      0.07
# Name: 1, dtype: float64
# i: 2, X_train: cDen    0.029126
# Pot     0.210526
# Sn %    0.500000
# pH      1.000000
# Name: 2, dtype: float64, y_train: C2H4    0.00
# H2      0.05
# Name: 2, dtype: float64
# i: 3, X_train: cDen    0.029126
# Pot     0.157895
# Sn %    0.100000
# pH      1.000000
# Name: 3, dtype: float64, y_train: C2H4    0.01
# H2      0.05
# Name: 3, dtype: float64
# i: 4, X_train: cDen    0.029126
# Pot     0.105263
# Sn %    0.050000
# pH      1.000000
# Name: 4, dtype: float64, y_train: C2H4    0.04
# H2      0.05
# Name: 4, dtype: float64
# i: 5, X_train: cDen    0.029126
# Pot     0.105263
# Sn %    0.030000
# pH      1.000000
# Name: 5, dtype: float64, y_train: C2H4    0.07
# H2      0.05
# Name: 5, dtype: float64
# i: 6, X_train: cDen    0.029126
# Pot     0.000000
# Sn %    0.000000
# pH      1.000000
# Name: 6, dtype: float64, y_train: C2H4    0.15
# H2      0.11
# Name: 6, dtype: float64
# i: 7, X_train: cDen    0.352751
# Pot     0.631579
# Sn %    1.000000
# pH      1.000000
# Name: 7, dtype: float64, y_train: C2H4    0.00
# H2      0.12
# Name: 7, dtype: float64
# i: 8, X_train: cDen    0.352751
# Pot     0.526316
# Sn %    0.800000
# pH      1.000000
# Name: 8, dtype: float64, y_train: C2H4    0.0
# H2      0.1
# Name: 8, dtype: float64
# i: 9, X_train: cDen    0.352751
# Pot     0.473684
# Sn %    0.500000
# pH      1.000000
# Name: 9, dtype: float64, y_train: C2H4    0.02
# H2      0.08
# Name: 9, dtype: float64
# i: 10, X_train: cDen    0.352751
# Pot     0.421053
# Sn %    0.100000
# pH      1.000000
# Name: 10, dtype: float64, y_train: C2H4    0.06
# H2      0.07
# Name: 10, dtype: float64
# i: 11, X_train: cDen    0.352751
# Pot     0.421053
# Sn %    0.050000
# pH      1.000000
# Name: 11, dtype: float64, y_train: C2H4    0.08
# H2      0.07
# Name: 11, dtype: float64
# i: 12, X_train: cDen    0.352751
# Pot     0.368421
# Sn %    0.030000
# pH      1.000000
# Name: 12, dtype: float64, y_train: C2H4    0.09
# H2      0.06
# Name: 12, dtype: float64
# i: 13, X_train: cDen    0.352751
# Pot     0.210526
# Sn %    0.000000
# pH      1.000000
# Name: 13, dtype: float64, y_train: C2H4    0.31
# H2      0.15
# Name: 13, dtype: float64
# i: 14, X_train: cDen    0.676375
# Pot     0.789474
# Sn %    1.000000
# pH      1.000000
# Name: 14, dtype: float64, y_train: C2H4    0.00
# H2      0.12
# Name: 14, dtype: float64
# i: 15, X_train: cDen    0.676375
# Pot     0.736842
# Sn %    0.800000
# pH      1.000000
# Name: 15, dtype: float64, y_train: C2H4    0.0
# H2      0.1
# Name: 15, dtype: float64
# i: 16, X_train: cDen    0.676375
# Pot     0.684211
# Sn %    0.500000
# pH      1.000000
# Name: 16, dtype: float64, y_train: C2H4    0.02
# H2      0.08
# Name: 16, dtype: float64
# i: 17, X_train: cDen    0.676375
# Pot     0.684211
# Sn %    0.100000
# pH      1.000000
# Name: 17, dtype: float64, y_train: C2H4    0.06
# H2      0.07
# Name: 17, dtype: float64
# i: 18, X_train: cDen    0.676375
# Pot     0.631579
# Sn %    0.050000
# pH      1.000000
# Name: 18, dtype: float64, y_train: C2H4    0.08
# H2      0.07
# Name: 18, dtype: float64
# i: 19, X_train: cDen    0.676375
# Pot     0.631579
# Sn %    0.030000
# pH      1.000000
# Name: 19, dtype: float64, y_train: C2H4    0.09
# H2      0.06
# Name: 19, dtype: float64
# i: 20, X_train: cDen    0.676375
# Pot     0.421053
# Sn %    0.000000
# pH      1.000000
# Name: 20, dtype: float64, y_train: C2H4    0.31
# H2      0.15
# Name: 20, dtype: float64
# i: 21, X_train: cDen    1.0
# Pot     1.0
# Sn %    1.0
# pH      1.0
# Name: 21, dtype: float64, y_train: C2H4    0.00
# H2      0.37
# Name: 21, dtype: float64
# i: 22, X_train: cDen    1.000000
# Pot     0.947368
# Sn %    0.800000
# pH      1.000000
# Name: 22, dtype: float64, y_train: C2H4    0.00
# H2      0.32
# Name: 22, dtype: float64
# i: 23, X_train: cDen    1.000000
# Pot     0.947368
# Sn %    0.500000
# pH      1.000000
# Name: 23, dtype: float64, y_train: C2H4    0.02
# H2      0.33
# Name: 23, dtype: float64
# i: 24, X_train: cDen    1.000000
# Pot     0.894737
# Sn %    0.100000
# pH      1.000000
# Name: 24, dtype: float64, y_train: C2H4    0.03
# H2      0.30
# Name: 24, dtype: float64
# i: 25, X_train: cDen    1.000000
# Pot     0.894737
# Sn %    0.050000
# pH      1.000000
# Name: 25, dtype: float64, y_train: C2H4    0.06
# H2      0.29
# Name: 25, dtype: float64
# i: 26, X_train: cDen    1.000000
# Pot     0.842105
# Sn %    0.030000
# pH      1.000000
# Name: 26, dtype: float64, y_train: C2H4    0.10
# H2      0.27
# Name: 26, dtype: float64
# i: 27, X_train: cDen    1.000000
# Pot     0.736842
# Sn %    0.000000
# pH      1.000000
# Name: 27, dtype: float64, y_train: C2H4    0.25
# H2      0.28
# Name: 27, dtype: float64
# i: 28, X_train: cDen    0.000000
# Pot     0.631579
# Sn %    1.000000
# pH      0.000000
# Name: 28, dtype: float64, y_train: C2H4    0.00
# H2      0.16
# Name: 28, dtype: float64
# i: 29, X_train: cDen    0.006472
# Pot     0.631579
# Sn %    0.800000
# pH      0.000000
# Name: 29, dtype: float64, y_train: C2H4    0.00
# H2      0.13
# Name: 29, dtype: float64
# i: 30, X_train: cDen    0.006472
# Pot     0.631579
# Sn %    0.500000
# pH      0.000000
# Name: 30, dtype: float64, y_train: C2H4    0.01
# H2      0.10
# Name: 30, dtype: float64
# i: 31, X_train: cDen    0.012945
# Pot     0.631579
# Sn %    0.100000
# pH      0.000000
# Name: 31, dtype: float64, y_train: C2H4    0.11
# H2      0.10
# Name: 31, dtype: float64
# i: 32, X_train: cDen    0.025890
# Pot     0.631579
# Sn %    0.050000
# pH      0.000000
# Name: 32, dtype: float64, y_train: C2H4    0.21
# H2      0.10
# Name: 32, dtype: float64
# i: 33, X_train: cDen    0.029126
# Pot     0.631579
# Sn %    0.030000
# pH      0.000000
# Name: 33, dtype: float64, y_train: C2H4    0.24
# H2      0.09
# Name: 33, dtype: float64
# i: 34, X_train: cDen    0.029126
# Pot     0.631579
# Sn %    0.000000
# pH      0.000000
# Name: 34, dtype: float64, y_train: C2H4    0.37
# H2      0.17
# Name: 34, dtype: float64

# %%
X_train.head(2)
# Out:
#        cDen       Pot  Sn %   pH
# 0  0.029126  0.368421   1.0  1.0
# 1  0.029126  0.263158   0.8  1.0

# %%
X_train.columns = ['x1', 'x2', 'x3', 'x4']

# %%
y_train = [polymer_properties(**row[1]) for row in X_train.iterrows()]

# %%
y_train
# Out:
# [{'C2H4': 0.003819656545782188, 'H2': 0.1154817319105637},
#  {'C2H4': 0.004521887106442371, 'H2': 0.07866365074761596},
#  {'C2H4': 0.022577450710898866, 'H2': 0.047680326185577715},
#  {'C2H4': 0.08206277222040526, 'H2': 0.05086580531316014},
#  {'C2H4': 0.09433071036870783, 'H2': 0.06584101721204484},
#  {'C2H4': 0.09787966617620139, 'H2': 0.06835975349974906},
#  {'C2H4': 0.10923458588036923, 'H2': 0.09421997695772155},
#  {'C2H4': -0.0033668195942405388, 'H2': 0.109791399289147},
#  {'C2H4': -0.002305250194943209, 'H2': 0.09999265282661446},
#  {'C2H4': 0.0260581821997862, 'H2': 0.07694884760077395},
#  {'C2H4': 0.11150067323763747, 'H2': 0.051462187101096915},
#  {'C2H4': 0.1221852161031444, 'H2': 0.05332185728690532},
#  {'C2H4': 0.13449798001204671, 'H2': 0.0704178307079611},
#  {'C2H4': 0.1607944741236078, 'H2': 0.12577272832353878},
#  {'C2H4': 0.00026932103069986224, 'H2': 0.13442989747984685},
#  {'C2H4': -3.403938923077221e-05, 'H2': 0.13141245267067347},
#  {'C2H4': 0.024913640860748557, 'H2': 0.11906227483575646},
#  {'C2H4': 0.09170520285265077, 'H2': 0.07708378823890488},
#  {'C2H4': 0.11008991817355787, 'H2': 0.07346645891225873},
#  {'C2H4': 0.1139889763373002, 'H2': 0.0736129762851521},
#  {'C2H4': 0.15644247677908407, 'H2': 0.10151761072108309},
#  {'C2H4': 0.013543507305906338, 'H2': 0.3265349355740676},
#  {'C2H4': 0.011505790404549507, 'H2': 0.32208731358363746},
#  {'C2H4': 0.02703119329787959, 'H2': 0.30513292423099253},
#  {'C2H4': 0.0869322076215197, 'H2': 0.2737805493261537},
#  {'C2H4': 0.09546056565812212, 'H2': 0.26956082580631535},
#  {'C2H4': 0.10654401186907989, 'H2': 0.26290307783531197},
#  {'C2H4': 0.12785148396756452, 'H2': 0.24620538101362377},
#  {'C2H4': 0.034246389894720376, 'H2': 0.15041321218395018},
#  {'C2H4': 0.0364868698760571, 'H2': 0.13551958102395453},
#  {'C2H4': 0.0794595460625318, 'H2': 0.09843330944910708},
#  {'C2H4': 0.20675902877331606, 'H2': 0.10329399966739213},
#  {'C2H4': 0.22158838107524048, 'H2': 0.11194760021377499},
#  {'C2H4': 0.22693104041578097, 'H2': 0.11571506815531776},
#  {'C2H4': 0.23415849401759015, 'H2': 0.12156146822588329}]

# %%
# Define the number of training examples
n_train = len(X_train)

ax_client = AxClient(random_seed=42) # CHANGE: add random seed for reproducibility

ax_client.create_experiment(
    parameters=[
        {"name": "x1", "type": "range", "bounds": [0.0, 1.0]}, # CHANGE: update parameter
        {"name": "x2", "type": "range", "bounds": [0.0, 1.0]}, # CHANGE: update parameter
        {"name": "x3", "type": "range", "bounds": [0.0, 1.0]}, # CHANGE: add new parameter
        {"name": "x4", "type": "range", "bounds": [0.0, 1.0]},
    ],
    objectives={
        obj1_name: ObjectiveProperties(minimize=False, threshold=0.0), # CHANGE: set minimize to False and change threshold
        obj2_name: ObjectiveProperties(minimize=True, threshold=0.0), # CHANGE: set minimize to False and change threshold
    }
)

# Add existing data to the AxClient
for i in range(n_train):
    parameterization = X_train.iloc[i].to_dict()

    ax_client.attach_trial(parameterization)
    ax_client.complete_trial(trial_index=i, raw_data=y_train[i])
# Out:
# [INFO 06-07 23:23:07] ax.service.ax_client: Starting optimization with verbose logging. To disable logging, set the `verbose_logging` argument to `False`. Note that float values in the logs are rounded to 6 decimal points.
# [WARNING 06-07 23:23:07] ax.service.ax_client: Random seed set to 42. Note that this setting only affects the Sobol quasi-random generator and BoTorch-powered Bayesian optimization models. For the latter models, setting random seed to the same number for two optimizations will make the generated trials similar, but not exactly the same, and over time the trials will diverge more.
# [INFO 06-07 23:23:07] ax.service.utils.instantiation: Inferred value type of ParameterType.FLOAT for parameter x1. If that is not the expected value type, you can explicity specify 'value_type' ('int', 'float', 'bool' or 'str') in parameter dict.
# [INFO 06-07 23:23:07] ax.service.utils.instantiation: Inferred value type of ParameterType.FLOAT for parameter x2. If that is not the expected value type, you can explicity specify 'value_type' ('int', 'float', 'bool' or 'str') in parameter dict.
# [INFO 06-07 23:23:07] ax.service.utils.instantiation: Inferred value type of ParameterType.FLOAT for parameter x3. If that is not the expected value type, you can explicity specify 'value_type' ('int', 'float', 'bool' or 'str') in parameter dict.
# [INFO 06-07 23:23:07] ax.service.utils.instantiation: Inferred value type of ParameterType.FLOAT for parameter x4. If that is not the expected value type, you can explicity specify 'value_type' ('int', 'float', 'bool' or 'str') in parameter dict.
# [INFO 06-07 23:23:07] ax.service.utils.instantiation: Created search space: SearchSpace(parameters=[RangeParameter(name='x1', parameter_type=FLOAT, range=[0.0, 1.0]), RangeParameter(name='x2', parameter_type=FLOAT, range=[0.0, 1.0]), RangeParameter(name='x3', parameter_type=FLOAT, range=[0.0, 1.0]), RangeParameter(name='x4', parameter_type=FLOAT, range=[0.0, 1.0])], parameter_constraints=[]).
# [INFO 06-07 23:23:07] ax.modelbridge.dispatch_utils: Using Models.MOO since there are more ordered parameters than there are categories for the unordered categorical parameters.
# [INFO 06-07 23:23:07] ax.modelbridge.dispatch_utils: Calculating the number of remaining initialization trials based on num_initialization_trials=None max_initialization_trials=None num_tunable_parameters=4 num_trials=None use_batch_trials=False
# [INFO 06-07 23:23:07] ax.modelbridge.dispatch_utils: calculated num_initialization_trials=8
# [INFO 06-07 23:23:07] ax.modelbridge.dispatch_utils: num_completed_initialization_trials=0 num_remaining_initialization_trials=8
# [INFO 06-07 23:23:07] ax.modelbridge.dispatch_utils: Using Bayesian Optimization generation strategy: GenerationStrategy(name='Sobol+MOO', steps=[Sobol for 8 trials, MOO for subsequent trials]). Iterations after 8 will take longer to generate due to model-fitting.
# [INFO 06-07 23:23:07] ax.core.experiment: Attached custom parameterizations [{'x1': 0.029126, 'x2': 0.368421, 'x3': 1.0, 'x4': 1.0}] as trial 0.
# [INFO 06-07 23:23:07] ax.service.ax_client: Completed trial 0 with data: {'C2H4': (0.00382, None), 'H2': (0.115482, None)}.
# [INFO 06-07 23:23:07] ax.core.experiment: Attached custom parameterizations [{'x1': 0.029126, 'x2': 0.263158, 'x3': 0.8, 'x4': 1.0}] as trial 1.
# [INFO 06-07 23:23:07] ax.service.ax_client: Completed trial 1 with data: {'C2H4': (0.004522, None), 'H2': (0.078664, None)}.
# [INFO 06-07 23:23:07] ax.core.experiment: Attached custom parameterizations [{'x1': 0.029126, 'x2': 0.210526, 'x3': 0.5, 'x4': 1.0}] as trial 2.
# [INFO 06-07 23:23:07] ax.service.ax_client: Completed trial 2 with data: {'C2H4': (0.022577, None), 'H2': (0.04768, None)}.
# [INFO 06-07 23:23:07] ax.core.experiment: Attached custom parameterizations [{'x1': 0.029126, 'x2': 0.157895, 'x3': 0.1, 'x4': 1.0}] as trial 3.
# [INFO 06-07 23:23:07] ax.service.ax_client: Completed trial 3 with data: {'C2H4': (0.082063, None), 'H2': (0.050866, None)}.
# [INFO 06-07 23:23:07] ax.core.experiment: Attached custom parameterizations [{'x1': 0.029126, 'x2': 0.105263, 'x3': 0.05, 'x4': 1.0}] as trial 4.
# [INFO 06-07 23:23:08] ax.service.ax_client: Completed trial 4 with data: {'C2H4': (0.094331, None), 'H2': (0.065841, None)}.
# [INFO 06-07 23:23:08] ax.core.experiment: Attached custom parameterizations [{'x1': 0.029126, 'x2': 0.105263, 'x3': 0.03, 'x4': 1.0}] as trial 5.
# [INFO 06-07 23:23:08] ax.service.ax_client: Completed trial 5 with data: {'C2H4': (0.09788, None), 'H2': (0.06836, None)}.
# [INFO 06-07 23:23:08] ax.core.experiment: Attached custom parameterizations [{'x1': 0.029126, 'x2': 0.0, 'x3': 0.0, 'x4': 1.0}] as trial 6.
# [INFO 06-07 23:23:08] ax.service.ax_client: Completed trial 6 with data: {'C2H4': (0.109235, None), 'H2': (0.09422, None)}.
# [INFO 06-07 23:23:08] ax.core.experiment: Attached custom parameterizations [{'x1': 0.352751, 'x2': 0.631579, 'x3': 1.0, 'x4': 1.0}] as trial 7.
# [INFO 06-07 23:23:08] ax.service.ax_client: Completed trial 7 with data: {'C2H4': (-0.003367, None), 'H2': (0.109791, None)}.
# [INFO 06-07 23:23:08] ax.core.experiment: Attached custom parameterizations [{'x1': 0.352751, 'x2': 0.526316, 'x3': 0.8, 'x4': 1.0}] as trial 8.
# [INFO 06-07 23:23:08] ax.service.ax_client: Completed trial 8 with data: {'C2H4': (-0.002305, None), 'H2': (0.099993, None)}.
# [INFO 06-07 23:23:08] ax.core.experiment: Attached custom parameterizations [{'x1': 0.352751, 'x2': 0.473684, 'x3': 0.5, 'x4': 1.0}] as trial 9.
# [INFO 06-07 23:23:08] ax.service.ax_client: Completed trial 9 with data: {'C2H4': (0.026058, None), 'H2': (0.076949, None)}.
# [INFO 06-07 23:23:08] ax.core.experiment: Attached custom parameterizations [{'x1': 0.352751, 'x2': 0.421053, 'x3': 0.1, 'x4': 1.0}] as trial 10.
# [INFO 06-07 23:23:08] ax.service.ax_client: Completed trial 10 with data: {'C2H4': (0.111501, None), 'H2': (0.051462, None)}.
# [INFO 06-07 23:23:08] ax.core.experiment: Attached custom parameterizations [{'x1': 0.352751, 'x2': 0.421053, 'x3': 0.05, 'x4': 1.0}] as trial 11.
# [INFO 06-07 23:23:08] ax.service.ax_client: Completed trial 11 with data: {'C2H4': (0.122185, None), 'H2': (0.053322, None)}.
# [INFO 06-07 23:23:08] ax.core.experiment: Attached custom parameterizations [{'x1': 0.352751, 'x2': 0.368421, 'x3': 0.03, 'x4': 1.0}] as trial 12.
# [INFO 06-07 23:23:08] ax.service.ax_client: Completed trial 12 with data: {'C2H4': (0.134498, None), 'H2': (0.070418, None)}.
# [INFO 06-07 23:23:08] ax.core.experiment: Attached custom parameterizations [{'x1': 0.352751, 'x2': 0.210526, 'x3': 0.0, 'x4': 1.0}] as trial 13.
# [INFO 06-07 23:23:08] ax.service.ax_client: Completed trial 13 with data: {'C2H4': (0.160794, None), 'H2': (0.125773, None)}.
# [INFO 06-07 23:23:08] ax.core.experiment: Attached custom parameterizations [{'x1': 0.676375, 'x2': 0.789474, 'x3': 1.0, 'x4': 1.0}] as trial 14.
# [INFO 06-07 23:23:08] ax.service.ax_client: Completed trial 14 with data: {'C2H4': (0.000269, None), 'H2': (0.13443, None)}.
# [INFO 06-07 23:23:08] ax.core.experiment: Attached custom parameterizations [{'x1': 0.676375, 'x2': 0.736842, 'x3': 0.8, 'x4': 1.0}] as trial 15.
# [INFO 06-07 23:23:08] ax.service.ax_client: Completed trial 15 with data: {'C2H4': (-3.4e-05, None), 'H2': (0.131412, None)}.
# [INFO 06-07 23:23:08] ax.core.experiment: Attached custom parameterizations [{'x1': 0.676375, 'x2': 0.684211, 'x3': 0.5, 'x4': 1.0}] as trial 16.
# [INFO 06-07 23:23:08] ax.service.ax_client: Completed trial 16 with data: {'C2H4': (0.024914, None), 'H2': (0.119062, None)}.
# [INFO 06-07 23:23:08] ax.core.experiment: Attached custom parameterizations [{'x1': 0.676375, 'x2': 0.684211, 'x3': 0.1, 'x4': 1.0}] as trial 17.
# [INFO 06-07 23:23:08] ax.service.ax_client: Completed trial 17 with data: {'C2H4': (0.091705, None), 'H2': (0.077084, None)}.
# [INFO 06-07 23:23:08] ax.core.experiment: Attached custom parameterizations [{'x1': 0.676375, 'x2': 0.631579, 'x3': 0.05, 'x4': 1.0}] as trial 18.
# [INFO 06-07 23:23:08] ax.service.ax_client: Completed trial 18 with data: {'C2H4': (0.11009, None), 'H2': (0.073466, None)}.
# [INFO 06-07 23:23:08] ax.core.experiment: Attached custom parameterizations [{'x1': 0.676375, 'x2': 0.631579, 'x3': 0.03, 'x4': 1.0}] as trial 19.
# [INFO 06-07 23:23:08] ax.service.ax_client: Completed trial 19 with data: {'C2H4': (0.113989, None), 'H2': (0.073613, None)}.
# [INFO 06-07 23:23:08] ax.core.experiment: Attached custom parameterizations [{'x1': 0.676375, 'x2': 0.421053, 'x3': 0.0, 'x4': 1.0}] as trial 20.
# [INFO 06-07 23:23:08] ax.service.ax_client: Completed trial 20 with data: {'C2H4': (0.156442, None), 'H2': (0.101518, None)}.
# [INFO 06-07 23:23:08] ax.core.experiment: Attached custom parameterizations [{'x1': 1.0, 'x2': 1.0, 'x3': 1.0, 'x4': 1.0}] as trial 21.
# [INFO 06-07 23:23:08] ax.service.ax_client: Completed trial 21 with data: {'C2H4': (0.013544, None), 'H2': (0.326535, None)}.
# [INFO 06-07 23:23:08] ax.core.experiment: Attached custom parameterizations [{'x1': 1.0, 'x2': 0.947368, 'x3': 0.8, 'x4': 1.0}] as trial 22.
# [INFO 06-07 23:23:08] ax.service.ax_client: Completed trial 22 with data: {'C2H4': (0.011506, None), 'H2': (0.322087, None)}.
# [INFO 06-07 23:23:08] ax.core.experiment: Attached custom parameterizations [{'x1': 1.0, 'x2': 0.947368, 'x3': 0.5, 'x4': 1.0}] as trial 23.
# [INFO 06-07 23:23:08] ax.service.ax_client: Completed trial 23 with data: {'C2H4': (0.027031, None), 'H2': (0.305133, None)}.
# [INFO 06-07 23:23:08] ax.core.experiment: Attached custom parameterizations [{'x1': 1.0, 'x2': 0.894737, 'x3': 0.1, 'x4': 1.0}] as trial 24.
# [INFO 06-07 23:23:08] ax.service.ax_client: Completed trial 24 with data: {'C2H4': (0.086932, None), 'H2': (0.273781, None)}.
# [INFO 06-07 23:23:08] ax.core.experiment: Attached custom parameterizations [{'x1': 1.0, 'x2': 0.894737, 'x3': 0.05, 'x4': 1.0}] as trial 25.
# [INFO 06-07 23:23:08] ax.service.ax_client: Completed trial 25 with data: {'C2H4': (0.095461, None), 'H2': (0.269561, None)}.
# [INFO 06-07 23:23:08] ax.core.experiment: Attached custom parameterizations [{'x1': 1.0, 'x2': 0.842105, 'x3': 0.03, 'x4': 1.0}] as trial 26.
# [INFO 06-07 23:23:08] ax.service.ax_client: Completed trial 26 with data: {'C2H4': (0.106544, None), 'H2': (0.262903, None)}.
# [INFO 06-07 23:23:08] ax.core.experiment: Attached custom parameterizations [{'x1': 1.0, 'x2': 0.736842, 'x3': 0.0, 'x4': 1.0}] as trial 27.
# [INFO 06-07 23:23:08] ax.service.ax_client: Completed trial 27 with data: {'C2H4': (0.127851, None), 'H2': (0.246205, None)}.
# [INFO 06-07 23:23:08] ax.core.experiment: Attached custom parameterizations [{'x1': 0.0, 'x2': 0.631579, 'x3': 1.0, 'x4': 0.0}] as trial 28.
# [INFO 06-07 23:23:08] ax.service.ax_client: Completed trial 28 with data: {'C2H4': (0.034246, None), 'H2': (0.150413, None)}.
# [INFO 06-07 23:23:08] ax.core.experiment: Attached custom parameterizations [{'x1': 0.006472, 'x2': 0.631579, 'x3': 0.8, 'x4': 0.0}] as trial 29.
# [INFO 06-07 23:23:08] ax.service.ax_client: Completed trial 29 with data: {'C2H4': (0.036487, None), 'H2': (0.13552, None)}.
# [INFO 06-07 23:23:08] ax.core.experiment: Attached custom parameterizations [{'x1': 0.006472, 'x2': 0.631579, 'x3': 0.5, 'x4': 0.0}] as trial 30.
# [INFO 06-07 23:23:08] ax.service.ax_client: Completed trial 30 with data: {'C2H4': (0.07946, None), 'H2': (0.098433, None)}.
# [INFO 06-07 23:23:08] ax.core.experiment: Attached custom parameterizations [{'x1': 0.012945, 'x2': 0.631579, 'x3': 0.1, 'x4': 0.0}] as trial 31.
# [INFO 06-07 23:23:08] ax.service.ax_client: Completed trial 31 with data: {'C2H4': (0.206759, None), 'H2': (0.103294, None)}.
# [INFO 06-07 23:23:08] ax.core.experiment: Attached custom parameterizations [{'x1': 0.02589, 'x2': 0.631579, 'x3': 0.05, 'x4': 0.0}] as trial 32.
# [INFO 06-07 23:23:08] ax.service.ax_client: Completed trial 32 with data: {'C2H4': (0.221588, None), 'H2': (0.111948, None)}.
# [INFO 06-07 23:23:08] ax.core.experiment: Attached custom parameterizations [{'x1': 0.029126, 'x2': 0.631579, 'x3': 0.03, 'x4': 0.0}] as trial 33.
# [INFO 06-07 23:23:08] ax.service.ax_client: Completed trial 33 with data: {'C2H4': (0.226931, None), 'H2': (0.115715, None)}.
# [INFO 06-07 23:23:08] ax.core.experiment: Attached custom parameterizations [{'x1': 0.029126, 'x2': 0.631579, 'x3': 0.0, 'x4': 0.0}] as trial 34.
# [INFO 06-07 23:23:08] ax.service.ax_client: Completed trial 34 with data: {'C2H4': (0.234158, None), 'H2': (0.121561, None)}.

# %%
for _ in range(100): # CHANGE: increase number of trials

    parameterization, trial_index = ax_client.get_next_trial()
    # CHANGE: pull all added parameters from the parameterization
    x1 = parameterization["x1"]
    x2 = parameterization["x2"]
    x3 = parameterization["x3"]
    x4 = parameterization["x4"]

    results = polymer_properties(x1, x2, x3, x4) 
    ax_client.complete_trial(trial_index=trial_index, raw_data=results)

pareto_results = ax_client.get_pareto_optimal_parameters()
# Out:
# [INFO 06-07 23:23:17] ax.service.ax_client: Generated new trial 35 with parameters {'x1': 0.997513, 'x2': 0.104366, 'x3': 0.822979, 'x4': 0.419432}.
# [INFO 06-07 23:23:17] ax.service.ax_client: Completed trial 35 with data: {'C2H4': (0.087805, None), 'H2': (0.155608, None)}.
# [INFO 06-07 23:23:17] ax.service.ax_client: Generated new trial 36 with parameters {'x1': 0.452701, 'x2': 0.838067, 'x3': 0.07327, 'x4': 0.61617}.
# [INFO 06-07 23:23:17] ax.service.ax_client: Completed trial 36 with data: {'C2H4': (0.110432, None), 'H2': (0.080426, None)}.
# [INFO 06-07 23:23:17] ax.service.ax_client: Generated new trial 37 with parameters {'x1': 0.218184, 'x2': 0.350223, 'x3': 0.697927, 'x4': 0.173966}.
# [INFO 06-07 23:23:17] ax.service.ax_client: Completed trial 37 with data: {'C2H4': (0.049572, None), 'H2': (0.131283, None)}.
# [INFO 06-07 23:23:17] ax.service.ax_client: Generated new trial 38 with parameters {'x1': 0.731992, 'x2': 0.584297, 'x3': 0.448306, 'x4': 0.853206}.
# [INFO 06-07 23:23:17] ax.service.ax_client: Completed trial 38 with data: {'C2H4': (0.052876, None), 'H2': (0.124676, None)}.
# [INFO 06-07 23:23:17] ax.service.ax_client: Generated new trial 39 with parameters {'x1': 0.586233, 'x2': 0.390302, 'x3': 0.154915, 'x4': 0.909619}.
# [INFO 06-07 23:23:17] ax.service.ax_client: Completed trial 39 with data: {'C2H4': (0.129919, None), 'H2': (0.089654, None)}.
# [INFO 06-07 23:23:17] ax.service.ax_client: Generated new trial 40 with parameters {'x1': 0.104163, 'x2': 0.686867, 'x3': 0.905394, 'x4': 0.11814}.
# [INFO 06-07 23:23:17] ax.service.ax_client: Completed trial 40 with data: {'C2H4': (0.026586, None), 'H2': (0.144751, None)}.
# [INFO 06-07 23:23:17] ax.service.ax_client: Generated new trial 41 with parameters {'x1': 0.369457, 'x2': 0.128742, 'x3': 0.27999, 'x4': 0.683748}.
# [INFO 06-07 23:23:17] ax.service.ax_client: Completed trial 41 with data: {'C2H4': (0.121303, None), 'H2': (0.133274, None)}.
# [INFO 06-07 23:23:18] ax.service.ax_client: Generated new trial 42 with parameters {'x1': 0.821007, 'x2': 0.924949, 'x3': 0.530305, 'x4': 0.351205}.
# [INFO 06-07 23:23:18] ax.service.ax_client: Completed trial 42 with data: {'C2H4': (0.062578, None), 'H2': (0.17251, None)}.
# [INFO 06-07 23:23:18] ax.service.ax_client: Generated new trial 43 with parameters {'x1': 0.104342, 'x2': 0.635652, 'x3': 0.016761, 'x4': 1.0}.
# [INFO 06-07 23:23:18] ax.service.ax_client: Completed trial 43 with data: {'C2H4': (0.081591, None), 'H2': (0.039526, None)}.
# [INFO 06-07 23:23:19] ax.service.ax_client: Generated new trial 44 with parameters {'x1': 0.0, 'x2': 0.41964, 'x3': 0.195717, 'x4': 0.671696}.
# [INFO 06-07 23:23:19] ax.service.ax_client: Completed trial 44 with data: {'C2H4': (0.084422, None), 'H2': (0.057881, None)}.
# [INFO 06-07 23:23:20] ax.service.ax_client: Generated new trial 45 with parameters {'x1': 0.36802, 'x2': 0.738259, 'x3': 0.0, 'x4': 1.0}.
# [INFO 06-07 23:23:20] ax.service.ax_client: Completed trial 45 with data: {'C2H4': (0.088893, None), 'H2': (0.021848, None)}.
# /Users/gbemidebe/miniconda3/envs/ActiveLearn/lib/python3.8/site-packages/botorch/optim/initializers.py:403: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# [INFO 06-07 23:23:21] ax.service.ax_client: Generated new trial 46 with parameters {'x1': 0.42661, 'x2': 0.622509, 'x3': 0.13585, 'x4': 0.444572}.
# [INFO 06-07 23:23:21] ax.service.ax_client: Completed trial 46 with data: {'C2H4': (0.14048, None), 'H2': (0.094885, None)}.
# /Users/gbemidebe/miniconda3/envs/ActiveLearn/lib/python3.8/site-packages/botorch/optim/initializers.py:403: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# [INFO 06-07 23:23:22] ax.service.ax_client: Generated new trial 47 with parameters {'x1': 0.42661, 'x2': 0.622509, 'x3': 0.13585, 'x4': 0.444572}.
# [INFO 06-07 23:23:22] ax.service.ax_client: Completed trial 47 with data: {'C2H4': (0.14048, None), 'H2': (0.094885, None)}.
# /Users/gbemidebe/miniconda3/envs/ActiveLearn/lib/python3.8/site-packages/botorch/optim/initializers.py:403: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# [INFO 06-07 23:23:23] ax.service.ax_client: Generated new trial 48 with parameters {'x1': 0.42661, 'x2': 0.622509, 'x3': 0.13585, 'x4': 0.444572}.
# [INFO 06-07 23:23:23] ax.service.ax_client: Completed trial 48 with data: {'C2H4': (0.14048, None), 'H2': (0.094885, None)}.
# /Users/gbemidebe/miniconda3/envs/ActiveLearn/lib/python3.8/site-packages/botorch/optim/initializers.py:403: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# [INFO 06-07 23:23:24] ax.service.ax_client: Generated new trial 49 with parameters {'x1': 0.42661, 'x2': 0.622509, 'x3': 0.13585, 'x4': 0.444572}.
# [INFO 06-07 23:23:24] ax.service.ax_client: Completed trial 49 with data: {'C2H4': (0.14048, None), 'H2': (0.094885, None)}.
# /Users/gbemidebe/miniconda3/envs/ActiveLearn/lib/python3.8/site-packages/botorch/optim/initializers.py:403: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# [INFO 06-07 23:23:25] ax.service.ax_client: Generated new trial 50 with parameters {'x1': 0.42661, 'x2': 0.622509, 'x3': 0.13585, 'x4': 0.444572}.
# [INFO 06-07 23:23:25] ax.service.ax_client: Completed trial 50 with data: {'C2H4': (0.14048, None), 'H2': (0.094885, None)}.
# /Users/gbemidebe/miniconda3/envs/ActiveLearn/lib/python3.8/site-packages/botorch/optim/initializers.py:403: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# [INFO 06-07 23:23:26] ax.service.ax_client: Generated new trial 51 with parameters {'x1': 0.42661, 'x2': 0.622509, 'x3': 0.13585, 'x4': 0.444572}.
# [INFO 06-07 23:23:26] ax.service.ax_client: Completed trial 51 with data: {'C2H4': (0.14048, None), 'H2': (0.094885, None)}.
# /Users/gbemidebe/miniconda3/envs/ActiveLearn/lib/python3.8/site-packages/botorch/optim/initializers.py:403: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# [INFO 06-07 23:23:27] ax.service.ax_client: Generated new trial 52 with parameters {'x1': 0.42661, 'x2': 0.622509, 'x3': 0.13585, 'x4': 0.444572}.
# [INFO 06-07 23:23:27] ax.service.ax_client: Completed trial 52 with data: {'C2H4': (0.14048, None), 'H2': (0.094885, None)}.
# /Users/gbemidebe/miniconda3/envs/ActiveLearn/lib/python3.8/site-packages/botorch/optim/initializers.py:403: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# [INFO 06-07 23:23:28] ax.service.ax_client: Generated new trial 53 with parameters {'x1': 0.42661, 'x2': 0.622509, 'x3': 0.13585, 'x4': 0.444572}.
# [INFO 06-07 23:23:28] ax.service.ax_client: Completed trial 53 with data: {'C2H4': (0.14048, None), 'H2': (0.094885, None)}.
# /Users/gbemidebe/miniconda3/envs/ActiveLearn/lib/python3.8/site-packages/botorch/optim/initializers.py:403: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# [INFO 06-07 23:23:30] ax.service.ax_client: Generated new trial 54 with parameters {'x1': 0.42661, 'x2': 0.622509, 'x3': 0.13585, 'x4': 0.444572}.
# [INFO 06-07 23:23:30] ax.service.ax_client: Completed trial 54 with data: {'C2H4': (0.14048, None), 'H2': (0.094885, None)}.
# /Users/gbemidebe/miniconda3/envs/ActiveLearn/lib/python3.8/site-packages/botorch/optim/initializers.py:403: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# [INFO 06-07 23:23:31] ax.service.ax_client: Generated new trial 55 with parameters {'x1': 0.42661, 'x2': 0.622509, 'x3': 0.13585, 'x4': 0.444572}.
# [INFO 06-07 23:23:31] ax.service.ax_client: Completed trial 55 with data: {'C2H4': (0.14048, None), 'H2': (0.094885, None)}.
# /Users/gbemidebe/miniconda3/envs/ActiveLearn/lib/python3.8/site-packages/botorch/optim/initializers.py:403: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# [INFO 06-07 23:23:32] ax.service.ax_client: Generated new trial 56 with parameters {'x1': 0.42661, 'x2': 0.622509, 'x3': 0.13585, 'x4': 0.444572}.
# [INFO 06-07 23:23:32] ax.service.ax_client: Completed trial 56 with data: {'C2H4': (0.14048, None), 'H2': (0.094885, None)}.
# /Users/gbemidebe/miniconda3/envs/ActiveLearn/lib/python3.8/site-packages/botorch/optim/initializers.py:403: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# [INFO 06-07 23:23:33] ax.service.ax_client: Generated new trial 57 with parameters {'x1': 0.42661, 'x2': 0.622509, 'x3': 0.13585, 'x4': 0.444572}.
# [INFO 06-07 23:23:33] ax.service.ax_client: Completed trial 57 with data: {'C2H4': (0.14048, None), 'H2': (0.094885, None)}.
# /Users/gbemidebe/miniconda3/envs/ActiveLearn/lib/python3.8/site-packages/botorch/optim/initializers.py:403: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# [INFO 06-07 23:23:34] ax.service.ax_client: Generated new trial 58 with parameters {'x1': 0.42661, 'x2': 0.622509, 'x3': 0.13585, 'x4': 0.444572}.
# [INFO 06-07 23:23:35] ax.service.ax_client: Completed trial 58 with data: {'C2H4': (0.14048, None), 'H2': (0.094885, None)}.
# /Users/gbemidebe/miniconda3/envs/ActiveLearn/lib/python3.8/site-packages/botorch/optim/initializers.py:403: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# [INFO 06-07 23:23:36] ax.service.ax_client: Generated new trial 59 with parameters {'x1': 0.42661, 'x2': 0.622509, 'x3': 0.13585, 'x4': 0.444572}.
# [INFO 06-07 23:23:36] ax.service.ax_client: Completed trial 59 with data: {'C2H4': (0.14048, None), 'H2': (0.094885, None)}.
# /Users/gbemidebe/miniconda3/envs/ActiveLearn/lib/python3.8/site-packages/botorch/optim/initializers.py:403: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# [INFO 06-07 23:23:37] ax.service.ax_client: Generated new trial 60 with parameters {'x1': 0.42661, 'x2': 0.622509, 'x3': 0.13585, 'x4': 0.444572}.
# [INFO 06-07 23:23:37] ax.service.ax_client: Completed trial 60 with data: {'C2H4': (0.14048, None), 'H2': (0.094885, None)}.
# /Users/gbemidebe/miniconda3/envs/ActiveLearn/lib/python3.8/site-packages/botorch/optim/initializers.py:403: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# [INFO 06-07 23:23:38] ax.service.ax_client: Generated new trial 61 with parameters {'x1': 0.42661, 'x2': 0.622509, 'x3': 0.13585, 'x4': 0.444572}.
# [INFO 06-07 23:23:38] ax.service.ax_client: Completed trial 61 with data: {'C2H4': (0.14048, None), 'H2': (0.094885, None)}.
# /Users/gbemidebe/miniconda3/envs/ActiveLearn/lib/python3.8/site-packages/botorch/optim/initializers.py:403: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# [INFO 06-07 23:23:40] ax.service.ax_client: Generated new trial 62 with parameters {'x1': 0.42661, 'x2': 0.622509, 'x3': 0.13585, 'x4': 0.444572}.
# [INFO 06-07 23:23:40] ax.service.ax_client: Completed trial 62 with data: {'C2H4': (0.14048, None), 'H2': (0.094885, None)}.
# /Users/gbemidebe/miniconda3/envs/ActiveLearn/lib/python3.8/site-packages/botorch/optim/initializers.py:403: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# [INFO 06-07 23:23:41] ax.service.ax_client: Generated new trial 63 with parameters {'x1': 0.42661, 'x2': 0.622509, 'x3': 0.13585, 'x4': 0.444572}.
# [INFO 06-07 23:23:41] ax.service.ax_client: Completed trial 63 with data: {'C2H4': (0.14048, None), 'H2': (0.094885, None)}.
# /Users/gbemidebe/miniconda3/envs/ActiveLearn/lib/python3.8/site-packages/botorch/optim/initializers.py:403: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# [INFO 06-07 23:23:42] ax.service.ax_client: Generated new trial 64 with parameters {'x1': 0.42661, 'x2': 0.622509, 'x3': 0.13585, 'x4': 0.444572}.
# [INFO 06-07 23:23:42] ax.service.ax_client: Completed trial 64 with data: {'C2H4': (0.14048, None), 'H2': (0.094885, None)}.
# /Users/gbemidebe/miniconda3/envs/ActiveLearn/lib/python3.8/site-packages/botorch/optim/initializers.py:403: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# [INFO 06-07 23:23:44] ax.service.ax_client: Generated new trial 65 with parameters {'x1': 0.42661, 'x2': 0.622509, 'x3': 0.13585, 'x4': 0.444572}.
# [INFO 06-07 23:23:44] ax.service.ax_client: Completed trial 65 with data: {'C2H4': (0.14048, None), 'H2': (0.094885, None)}.
# /Users/gbemidebe/miniconda3/envs/ActiveLearn/lib/python3.8/site-packages/botorch/optim/initializers.py:403: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# [INFO 06-07 23:23:46] ax.service.ax_client: Generated new trial 66 with parameters {'x1': 0.42661, 'x2': 0.622509, 'x3': 0.13585, 'x4': 0.444572}.
# [INFO 06-07 23:23:46] ax.service.ax_client: Completed trial 66 with data: {'C2H4': (0.14048, None), 'H2': (0.094885, None)}.
# /Users/gbemidebe/miniconda3/envs/ActiveLearn/lib/python3.8/site-packages/botorch/optim/initializers.py:403: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# [INFO 06-07 23:23:47] ax.service.ax_client: Generated new trial 67 with parameters {'x1': 0.42661, 'x2': 0.622509, 'x3': 0.13585, 'x4': 0.444572}.
# [INFO 06-07 23:23:47] ax.service.ax_client: Completed trial 67 with data: {'C2H4': (0.14048, None), 'H2': (0.094885, None)}.
# /Users/gbemidebe/miniconda3/envs/ActiveLearn/lib/python3.8/site-packages/botorch/optim/initializers.py:403: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# [INFO 06-07 23:23:49] ax.service.ax_client: Generated new trial 68 with parameters {'x1': 0.42661, 'x2': 0.622509, 'x3': 0.13585, 'x4': 0.444572}.
# [INFO 06-07 23:23:49] ax.service.ax_client: Completed trial 68 with data: {'C2H4': (0.14048, None), 'H2': (0.094885, None)}.
# /Users/gbemidebe/miniconda3/envs/ActiveLearn/lib/python3.8/site-packages/botorch/optim/initializers.py:403: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# [INFO 06-07 23:23:51] ax.service.ax_client: Generated new trial 69 with parameters {'x1': 0.42661, 'x2': 0.622509, 'x3': 0.13585, 'x4': 0.444572}.
# [INFO 06-07 23:23:51] ax.service.ax_client: Completed trial 69 with data: {'C2H4': (0.14048, None), 'H2': (0.094885, None)}.
# /Users/gbemidebe/miniconda3/envs/ActiveLearn/lib/python3.8/site-packages/botorch/optim/initializers.py:403: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# [INFO 06-07 23:23:53] ax.service.ax_client: Generated new trial 70 with parameters {'x1': 0.42661, 'x2': 0.622509, 'x3': 0.13585, 'x4': 0.444572}.
# [INFO 06-07 23:23:53] ax.service.ax_client: Completed trial 70 with data: {'C2H4': (0.14048, None), 'H2': (0.094885, None)}.
# /Users/gbemidebe/miniconda3/envs/ActiveLearn/lib/python3.8/site-packages/botorch/optim/initializers.py:403: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# [INFO 06-07 23:23:54] ax.service.ax_client: Generated new trial 71 with parameters {'x1': 0.42661, 'x2': 0.622509, 'x3': 0.13585, 'x4': 0.444572}.
# [INFO 06-07 23:23:54] ax.service.ax_client: Completed trial 71 with data: {'C2H4': (0.14048, None), 'H2': (0.094885, None)}.
# /Users/gbemidebe/miniconda3/envs/ActiveLearn/lib/python3.8/site-packages/botorch/optim/initializers.py:403: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# [INFO 06-07 23:23:56] ax.service.ax_client: Generated new trial 72 with parameters {'x1': 0.42661, 'x2': 0.622509, 'x3': 0.13585, 'x4': 0.444572}.
# [INFO 06-07 23:23:56] ax.service.ax_client: Completed trial 72 with data: {'C2H4': (0.14048, None), 'H2': (0.094885, None)}.
# /Users/gbemidebe/miniconda3/envs/ActiveLearn/lib/python3.8/site-packages/botorch/optim/initializers.py:403: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# [INFO 06-07 23:23:57] ax.service.ax_client: Generated new trial 73 with parameters {'x1': 0.42661, 'x2': 0.622509, 'x3': 0.13585, 'x4': 0.444572}.
# [INFO 06-07 23:23:57] ax.service.ax_client: Completed trial 73 with data: {'C2H4': (0.14048, None), 'H2': (0.094885, None)}.
# /Users/gbemidebe/miniconda3/envs/ActiveLearn/lib/python3.8/site-packages/botorch/optim/initializers.py:403: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# [INFO 06-07 23:23:59] ax.service.ax_client: Generated new trial 74 with parameters {'x1': 0.42661, 'x2': 0.622509, 'x3': 0.13585, 'x4': 0.444572}.
# [INFO 06-07 23:23:59] ax.service.ax_client: Completed trial 74 with data: {'C2H4': (0.14048, None), 'H2': (0.094885, None)}.
# /Users/gbemidebe/miniconda3/envs/ActiveLearn/lib/python3.8/site-packages/botorch/optim/initializers.py:403: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# [INFO 06-07 23:24:00] ax.service.ax_client: Generated new trial 75 with parameters {'x1': 0.42661, 'x2': 0.622509, 'x3': 0.13585, 'x4': 0.444572}.
# [INFO 06-07 23:24:00] ax.service.ax_client: Completed trial 75 with data: {'C2H4': (0.14048, None), 'H2': (0.094885, None)}.
# /Users/gbemidebe/miniconda3/envs/ActiveLearn/lib/python3.8/site-packages/botorch/optim/initializers.py:403: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# [INFO 06-07 23:24:02] ax.service.ax_client: Generated new trial 76 with parameters {'x1': 0.42661, 'x2': 0.622509, 'x3': 0.13585, 'x4': 0.444572}.
# [INFO 06-07 23:24:02] ax.service.ax_client: Completed trial 76 with data: {'C2H4': (0.14048, None), 'H2': (0.094885, None)}.
# /Users/gbemidebe/miniconda3/envs/ActiveLearn/lib/python3.8/site-packages/botorch/optim/initializers.py:403: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# [INFO 06-07 23:24:03] ax.service.ax_client: Generated new trial 77 with parameters {'x1': 0.42661, 'x2': 0.622509, 'x3': 0.13585, 'x4': 0.444572}.
# [INFO 06-07 23:24:03] ax.service.ax_client: Completed trial 77 with data: {'C2H4': (0.14048, None), 'H2': (0.094885, None)}.
# /Users/gbemidebe/miniconda3/envs/ActiveLearn/lib/python3.8/site-packages/botorch/optim/initializers.py:403: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# [INFO 06-07 23:24:05] ax.service.ax_client: Generated new trial 78 with parameters {'x1': 0.42661, 'x2': 0.622509, 'x3': 0.13585, 'x4': 0.444572}.
# [INFO 06-07 23:24:05] ax.service.ax_client: Completed trial 78 with data: {'C2H4': (0.14048, None), 'H2': (0.094885, None)}.
# /Users/gbemidebe/miniconda3/envs/ActiveLearn/lib/python3.8/site-packages/botorch/optim/initializers.py:403: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# [INFO 06-07 23:24:06] ax.service.ax_client: Generated new trial 79 with parameters {'x1': 0.42661, 'x2': 0.622509, 'x3': 0.13585, 'x4': 0.444572}.
# [INFO 06-07 23:24:06] ax.service.ax_client: Completed trial 79 with data: {'C2H4': (0.14048, None), 'H2': (0.094885, None)}.
# /Users/gbemidebe/miniconda3/envs/ActiveLearn/lib/python3.8/site-packages/botorch/optim/initializers.py:403: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# [INFO 06-07 23:24:08] ax.service.ax_client: Generated new trial 80 with parameters {'x1': 0.42661, 'x2': 0.622509, 'x3': 0.13585, 'x4': 0.444572}.
# [INFO 06-07 23:24:08] ax.service.ax_client: Completed trial 80 with data: {'C2H4': (0.14048, None), 'H2': (0.094885, None)}.
# /Users/gbemidebe/miniconda3/envs/ActiveLearn/lib/python3.8/site-packages/botorch/optim/initializers.py:403: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# [INFO 06-07 23:24:09] ax.service.ax_client: Generated new trial 81 with parameters {'x1': 0.42661, 'x2': 0.622509, 'x3': 0.13585, 'x4': 0.444572}.
# [INFO 06-07 23:24:09] ax.service.ax_client: Completed trial 81 with data: {'C2H4': (0.14048, None), 'H2': (0.094885, None)}.
# /Users/gbemidebe/miniconda3/envs/ActiveLearn/lib/python3.8/site-packages/botorch/optim/initializers.py:403: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# [INFO 06-07 23:24:10] ax.service.ax_client: Generated new trial 82 with parameters {'x1': 0.42661, 'x2': 0.622509, 'x3': 0.13585, 'x4': 0.444572}.
# [INFO 06-07 23:24:10] ax.service.ax_client: Completed trial 82 with data: {'C2H4': (0.14048, None), 'H2': (0.094885, None)}.
# /Users/gbemidebe/miniconda3/envs/ActiveLearn/lib/python3.8/site-packages/botorch/optim/initializers.py:403: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# [INFO 06-07 23:24:12] ax.service.ax_client: Generated new trial 83 with parameters {'x1': 0.42661, 'x2': 0.622509, 'x3': 0.13585, 'x4': 0.444572}.
# [INFO 06-07 23:24:12] ax.service.ax_client: Completed trial 83 with data: {'C2H4': (0.14048, None), 'H2': (0.094885, None)}.
# /Users/gbemidebe/miniconda3/envs/ActiveLearn/lib/python3.8/site-packages/botorch/optim/initializers.py:403: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# [INFO 06-07 23:24:14] ax.service.ax_client: Generated new trial 84 with parameters {'x1': 0.42661, 'x2': 0.622509, 'x3': 0.13585, 'x4': 0.444572}.
# [INFO 06-07 23:24:14] ax.service.ax_client: Completed trial 84 with data: {'C2H4': (0.14048, None), 'H2': (0.094885, None)}.
# /Users/gbemidebe/miniconda3/envs/ActiveLearn/lib/python3.8/site-packages/botorch/optim/initializers.py:403: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# [INFO 06-07 23:24:15] ax.service.ax_client: Generated new trial 85 with parameters {'x1': 0.42661, 'x2': 0.622509, 'x3': 0.13585, 'x4': 0.444572}.
# [INFO 06-07 23:24:15] ax.service.ax_client: Completed trial 85 with data: {'C2H4': (0.14048, None), 'H2': (0.094885, None)}.
# /Users/gbemidebe/miniconda3/envs/ActiveLearn/lib/python3.8/site-packages/botorch/optim/initializers.py:403: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# [INFO 06-07 23:24:17] ax.service.ax_client: Generated new trial 86 with parameters {'x1': 0.42661, 'x2': 0.622509, 'x3': 0.13585, 'x4': 0.444572}.
# [INFO 06-07 23:24:17] ax.service.ax_client: Completed trial 86 with data: {'C2H4': (0.14048, None), 'H2': (0.094885, None)}.
# /Users/gbemidebe/miniconda3/envs/ActiveLearn/lib/python3.8/site-packages/botorch/optim/initializers.py:403: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# [INFO 06-07 23:24:18] ax.service.ax_client: Generated new trial 87 with parameters {'x1': 0.42661, 'x2': 0.622509, 'x3': 0.13585, 'x4': 0.444572}.
# [INFO 06-07 23:24:18] ax.service.ax_client: Completed trial 87 with data: {'C2H4': (0.14048, None), 'H2': (0.094885, None)}.
# /Users/gbemidebe/miniconda3/envs/ActiveLearn/lib/python3.8/site-packages/botorch/optim/initializers.py:403: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# [INFO 06-07 23:24:20] ax.service.ax_client: Generated new trial 88 with parameters {'x1': 0.42661, 'x2': 0.622509, 'x3': 0.13585, 'x4': 0.444572}.
# [INFO 06-07 23:24:20] ax.service.ax_client: Completed trial 88 with data: {'C2H4': (0.14048, None), 'H2': (0.094885, None)}.
# /Users/gbemidebe/miniconda3/envs/ActiveLearn/lib/python3.8/site-packages/botorch/optim/initializers.py:403: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# [INFO 06-07 23:24:21] ax.service.ax_client: Generated new trial 89 with parameters {'x1': 0.42661, 'x2': 0.622509, 'x3': 0.13585, 'x4': 0.444572}.
# [INFO 06-07 23:24:21] ax.service.ax_client: Completed trial 89 with data: {'C2H4': (0.14048, None), 'H2': (0.094885, None)}.
# /Users/gbemidebe/miniconda3/envs/ActiveLearn/lib/python3.8/site-packages/botorch/optim/initializers.py:403: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# [INFO 06-07 23:24:23] ax.service.ax_client: Generated new trial 90 with parameters {'x1': 0.42661, 'x2': 0.622509, 'x3': 0.13585, 'x4': 0.444572}.
# [INFO 06-07 23:24:23] ax.service.ax_client: Completed trial 90 with data: {'C2H4': (0.14048, None), 'H2': (0.094885, None)}.
# /Users/gbemidebe/miniconda3/envs/ActiveLearn/lib/python3.8/site-packages/botorch/optim/initializers.py:403: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# [INFO 06-07 23:24:25] ax.service.ax_client: Generated new trial 91 with parameters {'x1': 0.42661, 'x2': 0.622509, 'x3': 0.13585, 'x4': 0.444572}.
# [INFO 06-07 23:24:25] ax.service.ax_client: Completed trial 91 with data: {'C2H4': (0.14048, None), 'H2': (0.094885, None)}.
# /Users/gbemidebe/miniconda3/envs/ActiveLearn/lib/python3.8/site-packages/botorch/optim/initializers.py:403: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# [INFO 06-07 23:24:26] ax.service.ax_client: Generated new trial 92 with parameters {'x1': 0.42661, 'x2': 0.622509, 'x3': 0.13585, 'x4': 0.444572}.
# [INFO 06-07 23:24:26] ax.service.ax_client: Completed trial 92 with data: {'C2H4': (0.14048, None), 'H2': (0.094885, None)}.
# /Users/gbemidebe/miniconda3/envs/ActiveLearn/lib/python3.8/site-packages/botorch/optim/initializers.py:403: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# [INFO 06-07 23:24:28] ax.service.ax_client: Generated new trial 93 with parameters {'x1': 0.42661, 'x2': 0.622509, 'x3': 0.13585, 'x4': 0.444572}.
# [INFO 06-07 23:24:28] ax.service.ax_client: Completed trial 93 with data: {'C2H4': (0.14048, None), 'H2': (0.094885, None)}.
# /Users/gbemidebe/miniconda3/envs/ActiveLearn/lib/python3.8/site-packages/botorch/optim/initializers.py:403: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# [INFO 06-07 23:24:30] ax.service.ax_client: Generated new trial 94 with parameters {'x1': 0.42661, 'x2': 0.622509, 'x3': 0.13585, 'x4': 0.444572}.
# [INFO 06-07 23:24:30] ax.service.ax_client: Completed trial 94 with data: {'C2H4': (0.14048, None), 'H2': (0.094885, None)}.
# /Users/gbemidebe/miniconda3/envs/ActiveLearn/lib/python3.8/site-packages/botorch/optim/initializers.py:403: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# [INFO 06-07 23:24:31] ax.service.ax_client: Generated new trial 95 with parameters {'x1': 0.42661, 'x2': 0.622509, 'x3': 0.13585, 'x4': 0.444572}.
# [INFO 06-07 23:24:31] ax.service.ax_client: Completed trial 95 with data: {'C2H4': (0.14048, None), 'H2': (0.094885, None)}.
# /Users/gbemidebe/miniconda3/envs/ActiveLearn/lib/python3.8/site-packages/botorch/optim/initializers.py:403: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# [INFO 06-07 23:24:33] ax.service.ax_client: Generated new trial 96 with parameters {'x1': 0.42661, 'x2': 0.622509, 'x3': 0.13585, 'x4': 0.444572}.
# [INFO 06-07 23:24:33] ax.service.ax_client: Completed trial 96 with data: {'C2H4': (0.14048, None), 'H2': (0.094885, None)}.
# /Users/gbemidebe/miniconda3/envs/ActiveLearn/lib/python3.8/site-packages/botorch/optim/initializers.py:403: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# [INFO 06-07 23:24:34] ax.service.ax_client: Generated new trial 97 with parameters {'x1': 0.42661, 'x2': 0.622509, 'x3': 0.13585, 'x4': 0.444572}.
# [INFO 06-07 23:24:34] ax.service.ax_client: Completed trial 97 with data: {'C2H4': (0.14048, None), 'H2': (0.094885, None)}.
# /Users/gbemidebe/miniconda3/envs/ActiveLearn/lib/python3.8/site-packages/botorch/optim/initializers.py:403: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# [INFO 06-07 23:24:36] ax.service.ax_client: Generated new trial 98 with parameters {'x1': 0.42661, 'x2': 0.622509, 'x3': 0.13585, 'x4': 0.444572}.
# [INFO 06-07 23:24:36] ax.service.ax_client: Completed trial 98 with data: {'C2H4': (0.14048, None), 'H2': (0.094885, None)}.
# /Users/gbemidebe/miniconda3/envs/ActiveLearn/lib/python3.8/site-packages/botorch/optim/initializers.py:403: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# [INFO 06-07 23:24:37] ax.service.ax_client: Generated new trial 99 with parameters {'x1': 0.42661, 'x2': 0.622509, 'x3': 0.13585, 'x4': 0.444572}.
# [INFO 06-07 23:24:37] ax.service.ax_client: Completed trial 99 with data: {'C2H4': (0.14048, None), 'H2': (0.094885, None)}.
# /Users/gbemidebe/miniconda3/envs/ActiveLearn/lib/python3.8/site-packages/botorch/optim/initializers.py:403: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# [INFO 06-07 23:24:38] ax.service.ax_client: Generated new trial 100 with parameters {'x1': 0.42661, 'x2': 0.622509, 'x3': 0.13585, 'x4': 0.444572}.
# [INFO 06-07 23:24:38] ax.service.ax_client: Completed trial 100 with data: {'C2H4': (0.14048, None), 'H2': (0.094885, None)}.
# /Users/gbemidebe/miniconda3/envs/ActiveLearn/lib/python3.8/site-packages/botorch/optim/initializers.py:403: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# [INFO 06-07 23:24:39] ax.service.ax_client: Generated new trial 101 with parameters {'x1': 0.42661, 'x2': 0.622509, 'x3': 0.13585, 'x4': 0.444572}.
# [INFO 06-07 23:24:39] ax.service.ax_client: Completed trial 101 with data: {'C2H4': (0.14048, None), 'H2': (0.094885, None)}.
# /Users/gbemidebe/miniconda3/envs/ActiveLearn/lib/python3.8/site-packages/botorch/optim/initializers.py:403: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# [INFO 06-07 23:24:41] ax.service.ax_client: Generated new trial 102 with parameters {'x1': 0.42661, 'x2': 0.622509, 'x3': 0.13585, 'x4': 0.444572}.
# [INFO 06-07 23:24:41] ax.service.ax_client: Completed trial 102 with data: {'C2H4': (0.14048, None), 'H2': (0.094885, None)}.
# /Users/gbemidebe/miniconda3/envs/ActiveLearn/lib/python3.8/site-packages/botorch/optim/initializers.py:403: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# [INFO 06-07 23:24:43] ax.service.ax_client: Generated new trial 103 with parameters {'x1': 0.42661, 'x2': 0.622509, 'x3': 0.13585, 'x4': 0.444572}.
# [INFO 06-07 23:24:43] ax.service.ax_client: Completed trial 103 with data: {'C2H4': (0.14048, None), 'H2': (0.094885, None)}.
# /Users/gbemidebe/miniconda3/envs/ActiveLearn/lib/python3.8/site-packages/botorch/optim/initializers.py:403: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# [INFO 06-07 23:24:44] ax.service.ax_client: Generated new trial 104 with parameters {'x1': 0.42661, 'x2': 0.622509, 'x3': 0.13585, 'x4': 0.444572}.
# [INFO 06-07 23:24:44] ax.service.ax_client: Completed trial 104 with data: {'C2H4': (0.14048, None), 'H2': (0.094885, None)}.
# /Users/gbemidebe/miniconda3/envs/ActiveLearn/lib/python3.8/site-packages/botorch/optim/initializers.py:403: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# [INFO 06-07 23:24:46] ax.service.ax_client: Generated new trial 105 with parameters {'x1': 0.42661, 'x2': 0.622509, 'x3': 0.13585, 'x4': 0.444572}.
# [INFO 06-07 23:24:46] ax.service.ax_client: Completed trial 105 with data: {'C2H4': (0.14048, None), 'H2': (0.094885, None)}.
# /Users/gbemidebe/miniconda3/envs/ActiveLearn/lib/python3.8/site-packages/botorch/optim/initializers.py:403: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# [INFO 06-07 23:24:47] ax.service.ax_client: Generated new trial 106 with parameters {'x1': 0.42661, 'x2': 0.622509, 'x3': 0.13585, 'x4': 0.444572}.
# [INFO 06-07 23:24:47] ax.service.ax_client: Completed trial 106 with data: {'C2H4': (0.14048, None), 'H2': (0.094885, None)}.
# /Users/gbemidebe/miniconda3/envs/ActiveLearn/lib/python3.8/site-packages/botorch/optim/initializers.py:403: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# [INFO 06-07 23:24:49] ax.service.ax_client: Generated new trial 107 with parameters {'x1': 0.42661, 'x2': 0.622509, 'x3': 0.13585, 'x4': 0.444572}.
# [INFO 06-07 23:24:49] ax.service.ax_client: Completed trial 107 with data: {'C2H4': (0.14048, None), 'H2': (0.094885, None)}.
# /Users/gbemidebe/miniconda3/envs/ActiveLearn/lib/python3.8/site-packages/botorch/optim/initializers.py:403: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# [INFO 06-07 23:24:51] ax.service.ax_client: Generated new trial 108 with parameters {'x1': 0.42661, 'x2': 0.622509, 'x3': 0.13585, 'x4': 0.444572}.
# [INFO 06-07 23:24:51] ax.service.ax_client: Completed trial 108 with data: {'C2H4': (0.14048, None), 'H2': (0.094885, None)}.
# /Users/gbemidebe/miniconda3/envs/ActiveLearn/lib/python3.8/site-packages/botorch/optim/initializers.py:403: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# [INFO 06-07 23:24:53] ax.service.ax_client: Generated new trial 109 with parameters {'x1': 0.42661, 'x2': 0.622509, 'x3': 0.13585, 'x4': 0.444572}.
# [INFO 06-07 23:24:53] ax.service.ax_client: Completed trial 109 with data: {'C2H4': (0.14048, None), 'H2': (0.094885, None)}.
# /Users/gbemidebe/miniconda3/envs/ActiveLearn/lib/python3.8/site-packages/botorch/optim/initializers.py:403: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# [INFO 06-07 23:24:55] ax.service.ax_client: Generated new trial 110 with parameters {'x1': 0.42661, 'x2': 0.622509, 'x3': 0.13585, 'x4': 0.444572}.
# [INFO 06-07 23:24:55] ax.service.ax_client: Completed trial 110 with data: {'C2H4': (0.14048, None), 'H2': (0.094885, None)}.
# /Users/gbemidebe/miniconda3/envs/ActiveLearn/lib/python3.8/site-packages/botorch/optim/initializers.py:403: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# [INFO 06-07 23:24:57] ax.service.ax_client: Generated new trial 111 with parameters {'x1': 0.42661, 'x2': 0.622509, 'x3': 0.13585, 'x4': 0.444572}.
# [INFO 06-07 23:24:57] ax.service.ax_client: Completed trial 111 with data: {'C2H4': (0.14048, None), 'H2': (0.094885, None)}.
# /Users/gbemidebe/miniconda3/envs/ActiveLearn/lib/python3.8/site-packages/botorch/optim/initializers.py:403: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# [INFO 06-07 23:24:59] ax.service.ax_client: Generated new trial 112 with parameters {'x1': 0.42661, 'x2': 0.622509, 'x3': 0.13585, 'x4': 0.444572}.
# [INFO 06-07 23:24:59] ax.service.ax_client: Completed trial 112 with data: {'C2H4': (0.14048, None), 'H2': (0.094885, None)}.
# /Users/gbemidebe/miniconda3/envs/ActiveLearn/lib/python3.8/site-packages/botorch/optim/initializers.py:403: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# [INFO 06-07 23:25:01] ax.service.ax_client: Generated new trial 113 with parameters {'x1': 0.42661, 'x2': 0.622509, 'x3': 0.13585, 'x4': 0.444572}.
# [INFO 06-07 23:25:01] ax.service.ax_client: Completed trial 113 with data: {'C2H4': (0.14048, None), 'H2': (0.094885, None)}.
# /Users/gbemidebe/miniconda3/envs/ActiveLearn/lib/python3.8/site-packages/botorch/optim/initializers.py:403: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# [INFO 06-07 23:25:03] ax.service.ax_client: Generated new trial 114 with parameters {'x1': 0.42661, 'x2': 0.622509, 'x3': 0.13585, 'x4': 0.444572}.
# [INFO 06-07 23:25:03] ax.service.ax_client: Completed trial 114 with data: {'C2H4': (0.14048, None), 'H2': (0.094885, None)}.
# /Users/gbemidebe/miniconda3/envs/ActiveLearn/lib/python3.8/site-packages/botorch/optim/initializers.py:403: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# [INFO 06-07 23:25:05] ax.service.ax_client: Generated new trial 115 with parameters {'x1': 0.42661, 'x2': 0.622509, 'x3': 0.13585, 'x4': 0.444572}.
# [INFO 06-07 23:25:05] ax.service.ax_client: Completed trial 115 with data: {'C2H4': (0.14048, None), 'H2': (0.094885, None)}.
# /Users/gbemidebe/miniconda3/envs/ActiveLearn/lib/python3.8/site-packages/botorch/optim/initializers.py:403: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# [INFO 06-07 23:25:07] ax.service.ax_client: Generated new trial 116 with parameters {'x1': 0.42661, 'x2': 0.622509, 'x3': 0.13585, 'x4': 0.444572}.
# [INFO 06-07 23:25:07] ax.service.ax_client: Completed trial 116 with data: {'C2H4': (0.14048, None), 'H2': (0.094885, None)}.
# /Users/gbemidebe/miniconda3/envs/ActiveLearn/lib/python3.8/site-packages/botorch/optim/initializers.py:403: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# [INFO 06-07 23:25:09] ax.service.ax_client: Generated new trial 117 with parameters {'x1': 0.42661, 'x2': 0.622509, 'x3': 0.13585, 'x4': 0.444572}.
# [INFO 06-07 23:25:09] ax.service.ax_client: Completed trial 117 with data: {'C2H4': (0.14048, None), 'H2': (0.094885, None)}.
# /Users/gbemidebe/miniconda3/envs/ActiveLearn/lib/python3.8/site-packages/botorch/optim/initializers.py:403: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# [INFO 06-07 23:25:11] ax.service.ax_client: Generated new trial 118 with parameters {'x1': 0.42661, 'x2': 0.622509, 'x3': 0.13585, 'x4': 0.444572}.
# [INFO 06-07 23:25:11] ax.service.ax_client: Completed trial 118 with data: {'C2H4': (0.14048, None), 'H2': (0.094885, None)}.
# /Users/gbemidebe/miniconda3/envs/ActiveLearn/lib/python3.8/site-packages/botorch/optim/initializers.py:403: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# [INFO 06-07 23:25:14] ax.service.ax_client: Generated new trial 119 with parameters {'x1': 0.42661, 'x2': 0.622509, 'x3': 0.13585, 'x4': 0.444572}.
# [INFO 06-07 23:25:14] ax.service.ax_client: Completed trial 119 with data: {'C2H4': (0.14048, None), 'H2': (0.094885, None)}.
# /Users/gbemidebe/miniconda3/envs/ActiveLearn/lib/python3.8/site-packages/botorch/optim/initializers.py:403: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# [INFO 06-07 23:25:16] ax.service.ax_client: Generated new trial 120 with parameters {'x1': 0.42661, 'x2': 0.622509, 'x3': 0.13585, 'x4': 0.444572}.
# [INFO 06-07 23:25:16] ax.service.ax_client: Completed trial 120 with data: {'C2H4': (0.14048, None), 'H2': (0.094885, None)}.
# /Users/gbemidebe/miniconda3/envs/ActiveLearn/lib/python3.8/site-packages/botorch/optim/initializers.py:403: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# [INFO 06-07 23:25:18] ax.service.ax_client: Generated new trial 121 with parameters {'x1': 0.42661, 'x2': 0.622509, 'x3': 0.13585, 'x4': 0.444572}.
# [INFO 06-07 23:25:18] ax.service.ax_client: Completed trial 121 with data: {'C2H4': (0.14048, None), 'H2': (0.094885, None)}.
# /Users/gbemidebe/miniconda3/envs/ActiveLearn/lib/python3.8/site-packages/botorch/optim/initializers.py:403: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# [INFO 06-07 23:25:20] ax.service.ax_client: Generated new trial 122 with parameters {'x1': 0.42661, 'x2': 0.622509, 'x3': 0.13585, 'x4': 0.444572}.
# [INFO 06-07 23:25:20] ax.service.ax_client: Completed trial 122 with data: {'C2H4': (0.14048, None), 'H2': (0.094885, None)}.
# /Users/gbemidebe/miniconda3/envs/ActiveLearn/lib/python3.8/site-packages/botorch/optim/initializers.py:403: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# [INFO 06-07 23:25:21] ax.service.ax_client: Generated new trial 123 with parameters {'x1': 0.42661, 'x2': 0.622509, 'x3': 0.13585, 'x4': 0.444572}.
# [INFO 06-07 23:25:21] ax.service.ax_client: Completed trial 123 with data: {'C2H4': (0.14048, None), 'H2': (0.094885, None)}.
# /Users/gbemidebe/miniconda3/envs/ActiveLearn/lib/python3.8/site-packages/botorch/optim/initializers.py:403: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# [INFO 06-07 23:25:24] ax.service.ax_client: Generated new trial 124 with parameters {'x1': 0.42661, 'x2': 0.622509, 'x3': 0.13585, 'x4': 0.444572}.
# [INFO 06-07 23:25:24] ax.service.ax_client: Completed trial 124 with data: {'C2H4': (0.14048, None), 'H2': (0.094885, None)}.
# /Users/gbemidebe/miniconda3/envs/ActiveLearn/lib/python3.8/site-packages/botorch/optim/initializers.py:403: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# [INFO 06-07 23:25:25] ax.service.ax_client: Generated new trial 125 with parameters {'x1': 0.42661, 'x2': 0.622509, 'x3': 0.13585, 'x4': 0.444572}.
# [INFO 06-07 23:25:25] ax.service.ax_client: Completed trial 125 with data: {'C2H4': (0.14048, None), 'H2': (0.094885, None)}.
# /Users/gbemidebe/miniconda3/envs/ActiveLearn/lib/python3.8/site-packages/botorch/optim/initializers.py:403: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# [INFO 06-07 23:25:27] ax.service.ax_client: Generated new trial 126 with parameters {'x1': 0.42661, 'x2': 0.622509, 'x3': 0.13585, 'x4': 0.444572}.
# [INFO 06-07 23:25:27] ax.service.ax_client: Completed trial 126 with data: {'C2H4': (0.14048, None), 'H2': (0.094885, None)}.
# /Users/gbemidebe/miniconda3/envs/ActiveLearn/lib/python3.8/site-packages/botorch/optim/initializers.py:403: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# [INFO 06-07 23:25:29] ax.service.ax_client: Generated new trial 127 with parameters {'x1': 0.42661, 'x2': 0.622509, 'x3': 0.13585, 'x4': 0.444572}.
# [INFO 06-07 23:25:29] ax.service.ax_client: Completed trial 127 with data: {'C2H4': (0.14048, None), 'H2': (0.094885, None)}.
# /Users/gbemidebe/miniconda3/envs/ActiveLearn/lib/python3.8/site-packages/botorch/optim/initializers.py:403: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# [INFO 06-07 23:25:31] ax.service.ax_client: Generated new trial 128 with parameters {'x1': 0.42661, 'x2': 0.622509, 'x3': 0.13585, 'x4': 0.444572}.
# [INFO 06-07 23:25:31] ax.service.ax_client: Completed trial 128 with data: {'C2H4': (0.14048, None), 'H2': (0.094885, None)}.
# /Users/gbemidebe/miniconda3/envs/ActiveLearn/lib/python3.8/site-packages/botorch/optim/initializers.py:403: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# [INFO 06-07 23:25:34] ax.service.ax_client: Generated new trial 129 with parameters {'x1': 0.42661, 'x2': 0.622509, 'x3': 0.13585, 'x4': 0.444572}.
# [INFO 06-07 23:25:34] ax.service.ax_client: Completed trial 129 with data: {'C2H4': (0.14048, None), 'H2': (0.094885, None)}.
# /Users/gbemidebe/miniconda3/envs/ActiveLearn/lib/python3.8/site-packages/botorch/optim/initializers.py:403: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# [INFO 06-07 23:25:37] ax.service.ax_client: Generated new trial 130 with parameters {'x1': 0.42661, 'x2': 0.622509, 'x3': 0.13585, 'x4': 0.444572}.
# [INFO 06-07 23:25:37] ax.service.ax_client: Completed trial 130 with data: {'C2H4': (0.14048, None), 'H2': (0.094885, None)}.
# /Users/gbemidebe/miniconda3/envs/ActiveLearn/lib/python3.8/site-packages/botorch/optim/initializers.py:403: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# [INFO 06-07 23:25:40] ax.service.ax_client: Generated new trial 131 with parameters {'x1': 0.42661, 'x2': 0.622509, 'x3': 0.13585, 'x4': 0.444572}.
# [INFO 06-07 23:25:40] ax.service.ax_client: Completed trial 131 with data: {'C2H4': (0.14048, None), 'H2': (0.094885, None)}.
# /Users/gbemidebe/miniconda3/envs/ActiveLearn/lib/python3.8/site-packages/botorch/optim/initializers.py:403: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# [INFO 06-07 23:25:42] ax.service.ax_client: Generated new trial 132 with parameters {'x1': 0.42661, 'x2': 0.622509, 'x3': 0.13585, 'x4': 0.444572}.
# [INFO 06-07 23:25:42] ax.service.ax_client: Completed trial 132 with data: {'C2H4': (0.14048, None), 'H2': (0.094885, None)}.
# /Users/gbemidebe/miniconda3/envs/ActiveLearn/lib/python3.8/site-packages/botorch/optim/initializers.py:403: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# [INFO 06-07 23:25:45] ax.service.ax_client: Generated new trial 133 with parameters {'x1': 0.42661, 'x2': 0.622509, 'x3': 0.13585, 'x4': 0.444572}.
# [INFO 06-07 23:25:45] ax.service.ax_client: Completed trial 133 with data: {'C2H4': (0.14048, None), 'H2': (0.094885, None)}.
# /Users/gbemidebe/miniconda3/envs/ActiveLearn/lib/python3.8/site-packages/botorch/optim/initializers.py:403: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# [INFO 06-07 23:25:48] ax.service.ax_client: Generated new trial 134 with parameters {'x1': 0.42661, 'x2': 0.622509, 'x3': 0.13585, 'x4': 0.444572}.
# [INFO 06-07 23:25:48] ax.service.ax_client: Completed trial 134 with data: {'C2H4': (0.14048, None), 'H2': (0.094885, None)}.

# %%
pareto_results
# Out:
# {}

# %%
p_op = ax_client.get_pareto_optimal_parameters()

# parse p_op values to get parameters and values
p_op_index = list(p_op.keys())
p_op_params = [p_op[i][0] for i in p_op_index]
p_op_values = [p_op[i][1][0] for i in p_op_index]

# organize the results into a dataframe
pareto_results = pd.DataFrame(p_op_params, columns=["x1", "x2", "x3", "x4"])
pareto_results["C2H4"] = [v["C2H4"] for v in p_op_values]
pareto_results["H2"] = [v["H2"] for v in p_op_values]
pareto_results.index = p_op_index
display(pareto_results.round(2))
# Out:
# [INFO 06-07 23:22:51] ax.modelbridge.torch: The observations are identical to the last set of observations used to fit the model. Skipping model fitting.
# Empty DataFrame
# Columns: [x1, x2, x3, x4, C2H4, H2]
# Index: []
